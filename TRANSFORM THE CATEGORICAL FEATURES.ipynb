# %% [markdown]
# # In this KERNEL we will transform the categorical features with non numeric data tyoe into Numeric data type using LabelEncoder

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#We can't give a dataframe to any Machine learning algorithm, and expect it to deal with the categorical feature which are not in
#numerical format. Its our prime duty to convert it beforehand. LabelEncoder does this in fractions of seconds and you don't
#have to worry about anything.
#Words of Wisdom-BEFORE APPLYING LabelEncoder, MAKE SURE YOUR DATA IN THAT PARTICULAR FEATURE IS CONSISTENT WITH NO NULL VALUES 
from sklearn.preprocessing import LabelEncoder

number=LabelEncoder()

# %%
sub=pd.read_csv('Submission.csv')
pat_mon_rev_train=pd.read_csv('patient_monthwise_revenue_train.csv')
pat_mon_rev_test=pd.read_csv('patient_monthwise_revenue_test.csv')
physio_diagnosis_train=pd.read_csv('physio_diagnosis_train.csv')
patient_train_classified=pd.read_csv('patient_train_classified.csv')
physio_appts_train=pd.read_csv('physio_appts_train.csv')
df=pd.read_csv('training_4.csv')
# Out:
# C:\Users\HarShreya\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2728: DtypeWarning: Columns (20,21) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# C:\Users\HarShreya\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2728: DtypeWarning: Columns (19) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
patient_train_classified.Bucket.value_counts()
# Out:
# Low         22411
# Med         17745
# High-Med     5334
# High         3314
# Name: Bucket, dtype: int64

# %%
df.head()
# Out:
#       pid  bucket  service  age  gender  city  ref_type  ref_name  ref_source  \
# 0  400061       3       10   62       1     3         1        77           4
# 1   25535       0       10   42       0     0         1       136           5
# 2  409013       3       10   67       1    21         1        91           5
# 3  164585       2       10   75       0    11         1       150           0
# 4   56960       2       10   63       1     3         1       150           9
#
#   avg_nps       s/c
# 0      10  0.500000
# 1      \N  0.741176
# 2      10  0.583333
# 3      \N  0.500000
# 4      \N  0.800000

# %%
df.gender.value_counts()
# Out:
# male      27200
# female    21529
# Name: gender, dtype: int64

# %%
df[(df.gender!='male')&(df.gender!='female')]
# Out:
# Empty DataFrame
# Columns: [pid, bucket, service, age, gender, city, ref_type, ref_name, ref_source, avg_nps, s/c]
# Index: []

# %%
df['gender']=number.fit_transform(df['gender'].astype('str'))

# %%
df[df.age=='\\N']
# Out:
# Empty DataFrame
# Columns: [pid, bucket, service, age, gender, city, ref_type, ref_name, ref_source, avg_nps, s/c]
# Index: []

# %%
df=std

# %%
age_ls=df[df.age=='\\N'].index.tolist()

# %%
df.age = pd.to_numeric(df.age, errors='coerce')

# %%
df.iloc[87].age=48
# Out:
# C:\Users\HarShreya\Anaconda3\lib\site-packages\pandas\core\generic.py:3643: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value

# %%
for i in age_ls:
# Out:
# [87,
#  90,
#  99,
#  112,
#  123,
#  125,
#  165,
#  197,
#  266,
#  269,
#  286,
#  374,
#  418,
#  459,
#  461,
#  471,
#  496,
#  508,
#  511,
#  544,
#  588,
#  606,
#  634,
#  640,
#  645,
#  683,
#  708,
#  709,
#  713,
#  714,
#  746,
#  827,
#  831,
#  838,
#  857,
#  887,
#  889,
#  890,
#  932,
#  939,
#  982,
#  1037,
#  1047,
#  1051,
#  1060,
#  1061,
#  1069,
#  1110,
#  1125,
#  1143,
#  1165,
#  1172,
#  1200,
#  1207,
#  1224,
#  1287,
#  1331,
#  1345,
#  1401,
#  1410,
#  1423,
#  1439,
#  1481,
#  1510,
#  1513,
#  1632,
#  1732,
#  1753,
#  1903,
#  1916,
#  1937,
#  1940,
#  1984,
#  2029,
#  2069,
#  2186,
#  2192,
#  2210,
#  2280,
#  2320,
#  2426,
#  2560,
#  2779,
#  2785,
#  2833,
#  2841,
#  2845,
#  3625,
#  4615,
#  4670,
#  4682,
#  4707,
#  4720,
#  4757,
#  4804,
#  4882,
#  4919,
#  5001,
#  5252,
#  5415,
#  5644,
#  5717,
#  5719,
#  5727,
#  6122,
#  6623,
#  6689,
#  6721,
#  7292,
#  7570,
#  7752,
#  7868,
#  7878,
#  7922,
#  8067,
#  8196,
# ...

# %%
for ind,rows in df.iterrows():
    if (rows.gender!='male')&(rows.gender!='female'):
        df.drop(df.index[ind],inplace=True)

# %%
 df.dropna(inplace=True)

# %%
df.to_csv('training_5.csv',index=False)

# %%
ls
# Out:
# [1572, 3070, 3384, 3894, 5066, 20946, 23456, 24992, 25749, 33702, 45182, 48446]

# %%
df.drop(labels=['diagnosis'],axis=1,inplace=True)

# %%
df.bucket.value_counts()
# Out:
# 2    22410
# 3    17740
# 1     5334
# 0     3314
# Name: bucket, dtype: int64

# %%
df['bucket']=number.fit_transform(df['bucket'].astype('str'))

# %%
df[df.age=='\\N']
# Out:
# Empty DataFrame
# Columns: [pid, bucket, service, age, gender, city, ref_type, ref_name, ref_source, avg_nps, s/c]
# Index: []

# %%
ls=[]
ls=df[(df.gender=='male')&(df.age!='\\N')].age.tolist()

# %%
ls1=[]
for i in ls:
    ls1.append(int(i))
si=pd.Series(ls1)

# %%
si.mean()
# Out:
# 47.058286358511836

# %%
df[(df.gender=='male')&(df.age=='\\N')].age.replace('47')
# Out:
# 89       \N
# 114      \N
# 125      \N
# 127      \N
# 167      \N
# 268      \N
# 288      \N
# 376      \N
# 420      \N
# 461      \N
# 463      \N
# 473      \N
# 510      \N
# 513      \N
# 546      \N
# 590      \N
# 608      \N
# 636      \N
# 647      \N
# 685      \N
# 710      \N
# 715      \N
# 716      \N
# 833      \N
# 840      \N
# 889      \N
# 891      \N
# 934      \N
# 1039     \N
# 1071     \N
#          ..
# 42550    \N
# 42552    \N
# 42580    \N
# 42607    \N
# 42675    \N
# 42726    \N
# 42808    \N
# 42841    \N
# 42973    \N
# 43070    \N
# 43091    \N
# 43373    \N
# 43422    \N
# 43531    \N
# 43534    \N
# 43577    \N
# 44034    \N
# 44035    \N
# 44112    \N
# 44331    \N
# 45445    \N
# 45590    \N
# 45726    \N
# 46096    \N
# 46303    \N
# 46702    \N
# 46865    \N
# 46890    \N
# 47148    \N
# 48057    \N
# Name: age, Length: 606, dtype: object

# %%
df.drop(df.index[3390],axis=0,inplace=True)

# %%
gen_index=[]
for index,rows in df.iterrows():
    if (rows.gender!='male')&(rows.gender!='female'):
        df.drop(df.index[index-1],axis=0,inplace=True)
        gen_index.append(index)

# %%
df.head()
# Out:
#       pid  bucket  service  age  gender  city  ref_type  ref_name  ref_source  \
# 0  400061       3       10   62       1     3         1        77           4
# 1   25535       0       10   42       0     0         1       136           5
# 2  409013       3       10   67       1    21         1        91           5
# 3  164585       2       10   75       0    11         1       150           0
# 4   56960       2       10   63       1     3         1       150           9
#
#         s/c
# 0  0.500000
# 1  0.741176
# 2  0.583333
# 3  0.500000
# 4  0.800000
