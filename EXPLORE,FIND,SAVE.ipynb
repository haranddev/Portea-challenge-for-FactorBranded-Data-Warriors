# %% [markdown]
# # In this Kernel we will
# # 1-Explore the PORTEA dataset provided
# # 2-Find out any patterns or common thread between several csv files
# # 3-Create a dataframe and store the key information of all of our findings for
# # further study

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
#importing some basic libraries

# %%
#Several files that were provided for the competition are being loaded in respective dataframes for study.
sub=pd.read_csv('Submission.csv')
pat_mon_rev_train=pd.read_csv('patient_monthwise_revenue_train.csv')
pat_mon_rev_test=pd.read_csv('patient_monthwise_revenue_test.csv')
physio_diagnosis_train=pd.read_csv('physio_diagnosis_train.csv')
patient_train_classified=pd.read_csv('patient_train_classified.csv')
physio_appts_train=pd.read_csv('physio_appts_train.csv')
# Out:
# C:\Users\HarShreya\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2728: DtypeWarning: Columns (20,21) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# C:\Users\HarShreya\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2728: DtypeWarning: Columns (19) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
#After exploring every dataset a bit, it was clear that one thread which is common in all datasets is 'patient_id' or 'pid'
#in some datasets for each 'pid' we have multiple observations and in some just one.
#on randomly selecting a pid=10714, pat_mon_rev_train dataset shows all the observations it has.
pat_mon_rev_train[pat_mon_rev_train.patient_id==10714]
# Out:
#     patient_id visit_month_year  service_id  visits_count       city  revenue  \
# 39       10714            01/14           2             5  Hyderabad   1000.0
# 40       10714            01/16           2             5  Hyderabad   2000.0
# 41       10714            10/14           2            12  Hyderabad   2400.0
# 42       10714            10/15           2             6  Hyderabad   2400.0
# 43       10714            10/16           2             3  Hyderabad   1200.0
# 44       10714            10/16          98             1  Hyderabad      0.0
# 45       10714            10/17           2             3  Hyderabad   1200.0
# 46       10714            10/17        4427             1  Hyderabad      0.0
# 47       10714            11/15           2             8  Hyderabad   3200.0
# 48       10714            11/16           2             2  Hyderabad    800.0
# 49       10714            12/15           2             8  Hyderabad   3200.0
# ...

# %%
pat_mon_rev_train[pat_mon_rev_train.patient_id==10381].avg_nps#.mode()
# Out:
# 2    8
# 3    8
# 4    8
# 5    8
# Name: avg_nps, dtype: object

# %%
physio_diagnosis_train[physio_diagnosis_train.patientId==10714]
# Out:
#    patientId                                      diagnosis        Service  \
# 7      10714  right hemiplegia,CVA WITH T\nRIGHT HEMIPLEGIA  physiotherapy
#
#   Appt_id AGE gender         LVD Unnamed: 7 Unnamed: 8
# 7  624323  62   male  27/10/2017        NaN        NaN

# %%
patient_train_classified[patient_train_classified.PID==10381]
# Out:
#          PID Bucket  Revenue
# 41181  10381   High  12250.0

# %%
physio_appts_train[(physio_appts_train.pat_id==10381) & (physio_appts_train.status=='successful')]
# Out:
#         appt_id  pat_id        startDateTime  serviceId                 name  \
# 109416   675822   10381  2015-07-31 16:00:00          2        Physiotherapy
# 110017   679254   10381  2015-08-06 11:30:00          2        Physiotherapy
# 110021   679258   10381  2015-08-08 14:00:00          2        Physiotherapy
# 110022   679259   10381  2015-08-09 14:00:00          2        Physiotherapy
# 110023   679260   10381  2015-08-04 14:00:00          2        Physiotherapy
# 110024   679261   10381  2015-08-11 10:00:00          2        Physiotherapy
# 110025   679262   10381  2015-08-12 10:00:00          2        Physiotherapy
# 110026   679263   10381  2015-08-05 14:00:00          2        Physiotherapy
# 111558   685154   10381  2015-08-07 12:00:00          2        Physiotherapy
# 111561   685157   10381  2015-08-14 12:00:00          2        Physiotherapy
# 111562   685186   10381  2015-08-13 16:00:00          2        Physiotherapy
# ...

# %%
physio_appts_train[physio_appts_train.pat_id==10388]
# Out:
#         appt_id  pat_id        startDateTime  serviceId           name  \
# 3          2785   10388  2014-01-04 10:00:00          2  Physiotherapy
# 5          3581   10388  2014-01-11 14:30:00          2  Physiotherapy
# 129464   779733   10388  2015-09-21 12:30:00          2  Physiotherapy
# 129471   779744   10388  2015-09-21 12:30:00          2  Physiotherapy
# 130644   783936   10388  2015-09-22 12:00:00          2  Physiotherapy
# 132052   788696   10388  2015-09-24 12:00:00          2  Physiotherapy
# 132337   789898   10388  2015-09-25 12:00:00          2  Physiotherapy
# 132338   789899   10388  2015-09-26 12:00:00          2  Physiotherapy
# 132339   789900   10388  2015-09-28 12:00:00          2  Physiotherapy
# 132340   789901   10388  2015-09-29 12:00:00          2  Physiotherapy
# 132341   789902   10388  2015-09-30 12:00:00          2  Physiotherapy
# 132342   789903   10388  2015-10-01 12:00:00          2  Physiotherapy
# ...

# %%
pat_mon_rev_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 83307 entries, 0 to 83306
# Data columns (total 20 columns):
# patient_id          83307 non-null int64
# visit_month_year    83307 non-null object
# service_id          83307 non-null int64
# visits_count        83307 non-null int64
# city                83307 non-null object
# revenue             83307 non-null float64
# ref_type            83307 non-null object
# ref_name            83307 non-null object
# ref_source          83307 non-null object
# service_name        82084 non-null object
# FVD                 83307 non-null object
# FVM                 83307 non-null object
# FVS                 83307 non-null object
# approx_age          83307 non-null object
# gender              83274 non-null object
# LVD                 83307 non-null object
# brand               83307 non-null object
# visits_required     83307 non-null int64
# diagnosis           81574 non-null object
# avg_nps             83307 non-null object
# ...

# %%
pat_mon_rev_train.drop(labels=['Unnamed: 20','Unnamed: 21'],axis=1,inplace=True)

# %%
pat_mon_rev_train
# Out:
#        patient_id visit_month_year  service_id  visits_count       city  \
# 0           10020            04/15           2             1    Chennai
# 1           10293            04/17           2             7     Mumbai
# 2           10381            07/15           2             1        NCR
# 3           10381            08/15           2            20        NCR
# 4           10381            08/15          98             1        NCR
# 5           10381            09/15           2             5        NCR
# 6           10388            01/14           2             1        NCR
# 7           10388            01/16           2             6        NCR
# 8           10388            01/16          98             1        NCR
# 9           10388            10/15           2            10        NCR
# 10          10388            11/15           2             7        NCR
# 11          10388            12/15           2             9        NCR
# ...

# %%
# Out:
# C:\Users\HarShreya\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2728: DtypeWarning: Columns (19) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
pat_mon_rev_test
# Out:
#        patient_id visit_month_year  service_id        city ref_type  \
# 0             122            01/14           2      Mumbai      B2C
# 1             122            01/15           2      Mumbai      B2C
# 2             122            11/13           2      Mumbai      B2C
# 3             122            11/14           2      Mumbai      B2C
# 4             122            12/13           2      Mumbai      B2C
# 5             122            12/14           2      Mumbai      B2C
# 6             122            02/14           2      Mumbai      B2C
# 7             122            02/15           2      Mumbai      B2C
# 8             122            03/14           2      Mumbai      B2C
# 9             122            03/15           2      Mumbai      B2C
# 10            122            04/14           2      Mumbai      B2C
# 11            122            05/14           2      Mumbai      B2C
# 12            129            11/13           2      Mumbai      B2C
# ...

# %%
pat_mon_rev_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55329 entries, 0 to 55328
# Data columns (total 18 columns):
# patient_id          55329 non-null int64
# visit_month_year    55329 non-null object
# service_id          55329 non-null int64
# city                55329 non-null object
# ref_type            55329 non-null object
# ref_name            55329 non-null object
# ref_source          55329 non-null object
# service_name        54477 non-null object
# FVD                 55329 non-null object
# FVM                 55329 non-null object
# FVS                 55329 non-null object
# approx_age          55329 non-null object
# gender              55298 non-null object
# LVD                 55329 non-null object
# brand               55329 non-null object
# visits_required     55329 non-null int64
# diagnosis           54162 non-null object
# avg_nps             55329 non-null object
# dtypes: int64(3), object(15)
# memory usage: 7.6+ MB

# %%
pat_mon_rev_test.drop(labels=['Unnamed: 18','Unnamed: 19'],axis=1,inplace=True)

# %%
physio_diagnosis_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48804 entries, 0 to 48803
# Data columns (total 7 columns):
# patientId    48804 non-null int64
# diagnosis    47748 non-null object
# Service      48804 non-null object
# Appt_id      48803 non-null object
# AGE          48804 non-null object
# gender       48775 non-null object
# LVD          48804 non-null object
# dtypes: int64(1), object(6)
# memory usage: 2.6+ MB

# %%
physio_diagnosis_train.drop(labels=['Unnamed: 7','Unnamed: 8'],axis=1,inplace=True)

# %%
physio_diagnosis_test=pd.read_csv('physio_diagnosis_test.csv')

# %%
ls2=pat_mon_rev_test['patient_id']

# %%
ls=(sub["PID"])

# %%
type(ls)
# Out:
# pandas.core.series.Series

# %%
ls1=(physio_diagnosis_test['patientId'])

# %%
#df1[~df1.isin(df2)].dropna()            rows of dataframe1 which are not in dataframe2
ls2[ls2.isin(ls)].dropna()
# Out:
# 0           122
# 1           122
# 2           122
# 3           122
# 4           122
# 5           122
# 6           122
# 7           122
# 8           122
# 9           122
# 10          122
# 11          122
# 12          129
# 13          129
# 14        10251
# 15        10251
# 16        10496
# 17        10496
# 18        10496
# 19        10496
# 20        10496
# 21        10496
# 22        10496
# 23        10496
# 24        10496
# 25        10496
# 26        10496
# 27        10496
# 28        10496
# 29        10496
#           ...
# 55299    453648
# 55300    453677
# 55301    453677
# 55302    453727
# 55303    453811
# 55304    453855
# 55305    453887
# 55306    453887
# 55307    453919
# 55308    453919
# 55309    453963
# 55310    453992
# 55311    453999
# 55312    454028
# 55313    454028
# 55314    454041
# 55315    454045
# 55316    454045
# 55317    454077
# 55318    454077
# 55319    454182
# 55320    454182
# 55321    454256
# 55322    454262
# ...

# %%
pat_mon_rev_train[pat_mon_rev_train.patient_id==400061]
# Out:
#        patient_id visit_month_year  service_id  visits_count       city  \
# 77414      400061            08/17           2             2  Bangalore
#
#        revenue ref_type ref_name     ref_source service_name     ...     FVS  \
# 77414   1200.0      B2C   Google  Digital + ATL            P     ...       P
#
#       approx_age  gender         LVD   brand visits_required diagnosis  \
# 77414         42  female  13/08/2017  Portea               7      PIVD
#
#        avg_nps Unnamed: 20 Unnamed: 21
# 77414       10         NaN         NaN
#
# [1 rows x 22 columns]

# %%
pat_mon_rev_train[pat_mon_rev_train.patient_id==53436].revenue.sum()
# Out:
# 95100.0

# %%
train_grouped=pat_mon_rev_train.groupby(by=['patient_id','visits_count']).groups

# %%
for name,group in train_grouped:
    print(name,'-',group)
    #print(group)
# Out:
# 10020 - 1
# 10293 - 7
# 10381 - 1
# 10381 - 5
# 10381 - 20
# 10388 - 1
# 10388 - 6
# 10388 - 7
# 10388 - 8
# 10388 - 9
# 10388 - 10
# 10388 - 14
# 10611 - 1
# 10611 - 6
# 10611 - 8
# 10670 - 1
# 10670 - 3
# 10670 - 4
# 10672 - 1
# 10672 - 5
# 10672 - 7
# 10672 - 9
# 10672 - 10
# 10672 - 15
# 10672 - 21
# 10672 - 22
# 10672 - 23
# 10672 - 24
# 10714 - 1
# 10714 - 2
# 10714 - 3
# 10714 - 5
# 10714 - 6
# 10714 - 7
# 10714 - 8
# 10714 - 11
# 10714 - 12
# 10714 - 16
# 10714 - 17
# 10714 - 19
# 10714 - 20
# 10714 - 21
# 10826 - 1
# 10826 - 13
# 10826 - 26
# 10841 - 2
# 10841 - 4
# 11193 - 1
# 11193 - 2
# 11193 - 3
# 11193 - 4
# 11193 - 6
# 11193 - 7
# 11193 - 8
# 11257 - 1
# 11462 - 1
# 11462 - 11
# 11480 - 1
# 11750 - 4
# 11883 - 1
# 11883 - 3
# 11883 - 4
# 11883 - 7
# 11949 - 1
# 11975 - 1
# 11975 - 2
# 11975 - 3
# 11975 - 4
# 11975 - 5
# 11975 - 6
# 11975 - 7
# 11975 - 8
# 11975 - 9
# 11975 - 10
# 11975 - 11
# 11975 - 15
# 12084 - 1
# 12084 - 2
# 12084 - 3
# 12089 - 1
# 12113 - 1
# ...

# %%
#For every patient some datasets have multiple observations and some have one.
#df dataframe would hold all the information related to patient from all the datasets.
#will start filling it with those first who are high, priority wise 
df=pd.DataFrame(columns=['pid','bucket'])

# %%
df.pid=patient_train_classified.PID
df.bucket=patient_train_classified.Bucket
df['diagnosis']=physio_diagnosis_train.diagnosis
df['service']=physio_diagnosis_train.Service
df['age']=physio_diagnosis_train.AGE
df['gender']=physio_diagnosis_train.gender
df['city']=c

# %%
#pat_mon_rev_train is the only dataset which has feature telling the city of the patient,
#but it has several observation of it. here the mode of the city coloumn of each patient is studied
#and mode of it is provided to df dataframe.
city=[]
for index,rows in df.iterrows():
    city.append(pat_mon_rev_train[pat_mon_rev_train.patient_id==rows.pid].city.mode())
    #print(rows.pid)
#df['city']=pd.Series(city)

c=[]
for i in city:
    c.append(str(i).split('\n')[0].split(' ')[4])
    

c=pd.Series(c)

c

# %%
#the above task for other important columns.
ref_type=[]
ref_name=[]
ref_source=[]
#ref_brand=[]
avg_nps=[]
for index,rows in df.iterrows():
    ref_type.append(pat_mon_rev_train[pat_mon_rev_train.patient_id==rows.pid].ref_type.mode())
    ref_name.append(pat_mon_rev_train[pat_mon_rev_train.patient_id==rows.pid].ref_name.mode())
    ref_source.append(pat_mon_rev_train[pat_mon_rev_train.patient_id==rows.pid].ref_source.mode())
    #ref_brand.append(pat_mon_rev_train[pat_mon_rev_train.patient_id==rows.pid].brand.mode())
    avg_nps.append(pat_mon_rev_train[pat_mon_rev_train.patient_id==rows.pid].avg_nps.mode())

# %%
#after the extraction and inestigation of some features, it came to be known that, we have to manipulate the type of the series
#aka feature. In most of the cases the conversion was difficult, therefore only key information was extracted and added

# %%
str(ref_brand[0]).split('\n')[0].split(' ')[4]
# Out:
# 'Portea'

# %%
ref1=[]
for i in ref_brand:
    ref1.append(str(ref_brand[0]).split('\n')[0].split(' ')[4])

# %%
df['ref_brand']=pd.Series(ref1)

# %%
pat_mon_rev_train.head()
# Out:
#    patient_id visit_month_year  service_id  visits_count     city  revenue  \
# 0       10020            04/15           2             1  Chennai    500.0
# 1       10293            04/17           2             7   Mumbai   4900.0
# 2       10381            07/15           2             1      NCR    500.0
# 3       10381            08/15           2            20      NCR   9500.0
# 4       10381            08/15          98             1      NCR      0.0
#
#   ref_type  ref_name      ref_source service_name     ...     FVS approx_age  \
# 0      B2C      None  Direct Organic            P     ...       P         62
# 1      B2C  Facebook   Digital + ATL            P     ...       P         42
# 2      B2C      None  Direct Organic            P     ...       P         67
# 3      B2C      None  Direct Organic            P     ...       P         67
# 4      B2C      None  Direct Organic            P     ...       P         67
#
#    gender         LVD   brand visits_required  \
# ...

# %%
pat_mon_rev_train.columns
# Out:
# Index(['patient_id', 'visit_month_year', 'service_id', 'visits_count', 'city',
#        'revenue', 'ref_type', 'ref_name', 'ref_source', 'service_name', 'FVD',
#        'FVM', 'FVS', 'approx_age', 'gender', 'LVD', 'brand', 'visits_required',
#        'diagnosis', 'avg_nps', 'Unnamed: 20', 'Unnamed: 21'],
#       dtype='object')

# %%
df.to_csv('Training_in_making_1.csv',index=False)
